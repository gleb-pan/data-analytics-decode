# %% [markdown]
# # Прошу прощения, что так поздно сдаю. Были дела и мне на время пришлось сфокусироваться на других делах...

# %%
import pandas as pd
df = pd.read_csv('../datasets/real_estate_data.csv', sep='\t')
df = df.drop_duplicates()

# %% [markdown]
# # 1. Предобработайте данные по недвижимости и оставьте только те города, в которых количество объявлений больше 50

# %%
# получаю таблицу с количеством объявлений по городам
over_fifty = df.groupby('locality_name').agg({'total_images': 'count'})

# %%
# изменияю название колонны для удобства
over_fifty = over_fifty.rename({'total_images': 'amount'}, axis=1)

# %%
# получаю таблицу с кол-вом объявлений больше 50шт., отстортированную по убыванию
over_fifty = over_fifty.query('amount > 50').sort_values('amount', ascending=False).reset_index()

# %%
'''
Произвожу слияние таблиц (over_fifty and df), для того чтобы получить оригинальный 
датасет, но содержащий города в которых кол-во объявлений больше 50шт.
Использовать буду параметр inner, так как он самый подходящий в этом случае
Колонна по которой будет происходить отбор - locality_name
'''
data = df.merge(over_fifty, on=['locality_name'], how='inner')

# %%
# проверка. визуально мы видим что кол-во объявлений в таблице data всегда больше 50
test = data.groupby('locality_name').agg({'total_images': 'count'})
test = test.rename({'total_images': 'amount'}, axis=1)
test
# Out:
#                            amount
# locality_name
# Волхов                        111
# Всеволожск                    398
# Выборг                        237
# Гатчина                       307
# Кингисепп                     104
# Кириши                        125
# Кировск                        84
# Колпино                       338
# Коммунар                       89
# Красное Село                  178
# Кронштадт                      96
# Кудрово                       173
# Ломоносов                     133
# Луга                           56
# Никольское                     93
# Отрадное                       80
# Петергоф                      201
# Приозерск                      66
# Пушкин                        369
# Санкт-Петербург             15721
# Сертолово                     142
# Сестрорецк                    183
# Сланцы                        112
# Сосновый Бор                   87
# Тосно                         104
# Шлиссельбург                   57
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21636 entries, 0 to 21635
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          21636 non-null  int64
#  1   last_price            21636 non-null  float64
#  2   total_area            21636 non-null  float64
#  3   first_day_exposition  21636 non-null  object
#  4   rooms                 21636 non-null  int64
#  5   ceiling_height        13380 non-null  float64
#  6   floors_total          21557 non-null  float64
#  7   living_area           19959 non-null  float64
#  8   floor                 21636 non-null  int64
#  9   is_apartment          2552 non-null   object
#  10  studio                21636 non-null  bool
#  11  open_plan             21636 non-null  bool
#  12  kitchen_area          19589 non-null  float64
#  13  balcony               11097 non-null  float64
#  14  locality_name         21636 non-null  object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# # 2. Постройте круговую диаграмму по сумме цен на недвижимость, разбитых по городам
# # +
# # 3. Добавьте надписи на круговую диаграмму и распишите какой параметр для этого используется.

# %%
import matplotlib.pyplot as plt

# создам таблицу в соответствии с заданием
# если я правильно понял то нужно использовать таблицу где кол-во объявлений больше 50, как исходную (data в моем случае)
chart = data.groupby('locality_name').agg({'last_price': 'sum'}).reset_index().sort_values('last_price', ascending=False)

# цифры слишком большие, поэтому разделю их на 1 000 000
# результат положу в новый столбец
chart['price_mln'] = round(chart['last_price'] / 1000000, 2)
# chart

# подготовим переменные для чарта
sizes = chart['price_mln'] # таблица с числами для построения круговой диаграммы
labels = chart['locality_name'] # беру стоблец который содержит только имена городов для добавления надписей на пайчарт

plt.pie(sizes, labels=labels, autopct='%1.1f%%') # в методе используем соответсвующий медод labels для вывода пайчарта с надписями
# autopct='%1.1f%%' - я загуглил данный аргумент, он нужен для добавления процентов на пайчарт. Все таки это тоже надписи)

plt.show()

# %%
# сдеолаю то же самое используя оригинальный датасет, для сравнения
chart2 = df.groupby('locality_name').agg({'last_price': 'sum'}).reset_index().sort_values('last_price', ascending=False)
chart2['price_mln'] = round(chart2['last_price'] / 1000000, 2)

sizes2 = chart2['price_mln']
labels2 = chart2['locality_name']

plt.pie(sizes2, labels=labels2, autopct='%1.1f%%')
plt.show()

# в данном пайчарте больше городов так как в нем присутвуют все позиции, даже те где кол-во объявлений меньше 50

# %%
chart3 = chart2.query("locality_name != 'Санкт-Петербург'")

labels3 = chart3['locality_name']
sizes3 = chart3['price_mln']

plt.pie(sizes3, labels=labels3)
plt.show()


# chart3 = data2.groupby('locality_name').agg({'price_mln': 'sum'}).reset_index()
# chart3

# %%
chart3
# Out:
#                            locality_name    last_price  price_mln
# 32                                Пушкин  2.387074e+09    2387.07
# 291                       посёлок Мурино  1.916810e+09    1916.81
# 326                       посёлок Шушары  1.807556e+09    1807.56
# 3                             Всеволожск  1.508049e+09    1508.05
# 296                    посёлок Парголово  1.467600e+09    1467.60
# ..                                   ...           ...        ...
# 238                     поселок Тёсово-4  7.500000e+05       0.75
# 249  поселок городского типа Кондратьево  7.500000e+05       0.75
# 243                      поселок Цвылёво  6.500000e+05       0.65
# 156                  деревня Чудской Бор  5.000000e+05       0.50
# 71                  деревня Вахнова Кара  4.500000e+05       0.45
#
# [363 rows x 3 columns]

# %% [markdown]
# # 4. Опишите выводы, исходя из круговой диаграммы, в ячейке типа markdown.
#
# - На чарте мы видим долю которую занимает тот или иной город на рынке недвижимости в области возле Санкт-Питербурга.
# - Например: Санкт-Петербург доминирует в списке городов и сум цен на недвижимость в этих городах. Весь рынок по сути сконцентрирован в этом городе. Это нам и показывает пай-чарт.
# - Можно сказать также, что чем больше стоимость (сумма), тем больше город.
# - Также, сумма отражает то насколько город популярен.

# %% [markdown]
# # 5. Постройте тепловую карту

# %%
import seaborn as sns

# %%
heatmap_data = data.corr(numeric_only=True) # получаем матрицу корреляций только по числовым (numeric_only) значениям

# %%
sns.heatmap(data=heatmap_data) # строим тепловую карту
# Out:
# <Axes: >

# %% [markdown]
# # 6. Опишите интересные вам взаимосвязи
#
# - интересно что очень незначительная взаимосвязь между ценой и локациями (парки, центр города). Я ожидал увидеть показатели выше, так как данный параметр часто имеет значение при продаже квартиры.
# - очевидно что стоимость зависит от размеров квартиры (размер кухни тоже), где мы и видим в высокую корреляцию.
# - также странно, что этаж и кол-во этажей в доме сильно не влияют на стоимость квартиры.

# %% [markdown]
# # 7. Постройте график распределения цен на недвижимость по городам

# %%
dis_data = data['last_price']/1_000_000
sns.displot(dis_data)

# %%
dis_data2 = data.query('locality_name != "Санкт-Петербург"')['last_price']/1_000_000
# sns.displot(data=dis_data)

# %%
sns.displot(data=dis_data2)

# %% [markdown]
# - При подаче данных в снс я делю суммы на 1 000 000 чтобы цифры в оси Х были более читаемыми.
#
# - При выполнении заданий я заметил что Санкт-петербург сильно портит графики, и поэтому я дополнительно делаю то же самое без него.
#
# - На первом графике распределения видно что все цены на недвижимость сконцентрированы в пределах от 0 до 20.
#
# - Это и подтверждает график2 но тут мы видим цифры точнее и можем сказать что наибольшее скопление именно в пределах от 0.1 до, примерно, 6.5.

# %% [markdown]
# # 9. Теперь постройте график распределения цен на недвижимость по количеству комнат

# %%
test = data[['locality_name', 'last_price', 'rooms']]
test['last_price'] = test['last_price']/1_000_000
test = test.query('locality_name != "Санкт-Петербург"')

sns.displot(test.query('last_price < 10'), x='rooms', y='last_price')


#test['last_price'].unique()
# Out:
# C:\Users\Gleb\AppData\Local\Temp\ipykernel_1900\3734020711.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['last_price'] = test['last_price']/1_000_000
